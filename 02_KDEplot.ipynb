# %% [markdown]
# # Seaborn: KDEplot

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
cars = sns.load_dataset('mpg').dropna()

cars.shape
# Out:
# (392, 9)

# %%
cars
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [392 rows x 9 columns]

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ## Intro Visuals

# %%
hp = cars.horsepower

# %%
hp
# Out:
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
#        ...
# 393     86.0
# 394     52.0
# 395     84.0
# 396     79.0
# 397     82.0
# Name: horsepower, Length: 392, dtype: float64

# %%
hp = cars.horsepower.to_frame()
hp
# Out:
#      horsepower
# 0         130.0
# 1         165.0
# 2         150.0
# 3         150.0
# 4         140.0
# ..          ...
# 393        86.0
# 394        52.0
# 395        84.0
# 396        79.0
# 397        82.0
#
# [392 rows x 1 columns]

# %%
hp = hp.rename(columns={'horsepower': 'hp'})
hp
# Out:
#         hp
# 0    130.0
# 1    165.0
# 2    150.0
# 3    150.0
# 4    140.0
# ..     ...
# 393   86.0
# 394   52.0
# 395   84.0
# 396   79.0
# 397   82.0
#
# [392 rows x 1 columns]

# %%
sns.set_style('white')
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)

# %%
plt.figure(figsize=(8,5))
sns.distplot(hp, rug=True, kde=False, hist=False)

sns.despine(left=True)
plt.xlim(0, 280)
plt.xlabel('')
plt.yticks([])
plt.tight_layout();
# Out:
# C:\Users\dghos\AppData\Local\Temp\ipykernel_5728\1367877438.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(hp, rug=True, kde=False, hist=False)

# %%
plt.figure(figsize=(8,5))
sns.distplot(hp, kde=False)

sns.despine(left=True)
plt.xlim(0, 280)
plt.xlabel('')
plt.yticks([])
plt.tight_layout();
# Out:
# C:\Users\dghos\AppData\Local\Temp\ipykernel_5728\3663483492.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(hp, kde=False)

# %%
plt.figure(figsize=(8,5))
sns.distplot(hp, kde_kws={"lw": 5}, hist_kws={'alpha': 0.25})

sns.despine(left=True)
plt.xlim(0, 280)
plt.xlabel('')
plt.yticks([])
plt.tight_layout();
# Out:
# C:\Users\dghos\AppData\Local\Temp\ipykernel_5728\570118453.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(hp, kde_kws={"lw": 5}, hist_kws={'alpha': 0.25})

# %% [markdown]
# ## "How It Works" Visuals

# %%
import numpy as np
import scipy.stats as stats

# %%
blue, orange, green, red = sns.color_palette()[:4]

# %%
pts = [1, 3, 3.5, 4, 6, 8]

# %%
plt.figure(figsize=(8, 5))
plt.scatter(pts, [0]*len(pts), s=100, zorder=1)
plt.axhline(0, color='gray', zorder=0)
plt.ylim(-0.1, 1.5)
plt.xlim(-3, 12)
plt.box(False)
plt.xticks(range(9))
plt.yticks([])
plt.tight_layout();

# %%
for i in range(len(pts)):
    plt.figure(figsize=(8, 5))
    for point in pts[0:i+1]:
        mu = point
        variance = 1
        sigma = np.sqrt(variance)
        x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
        plt.plot(x, stats.norm.pdf(x, mu, sigma), linestyle='--', color='gray', zorder=2)
    plt.scatter(pts, [0]*len(pts), s=100, zorder=1)
    plt.axhline(0, color='gray', zorder=0)
    plt.xlim(-3, 12)
    plt.ylim(-0.1, 1.5)
    plt.box(False)
    plt.xticks(range(9))
    plt.yticks([])
    plt.tight_layout();
    #plt.savefig(f'02KDE_kernel{i}.svg');

# %%
for i in range(1, len(pts)+1):
    plt.figure(figsize=(8, 5))
    for point in pts[0:len(pts)+1]:
        mu = point
        variance = 1
        sigma = np.sqrt(variance)
        x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
        plt.plot(x, stats.norm.pdf(x, mu, sigma), linestyle='--', color='gray', zorder=2)
    plt.scatter(pts, [0]*len(pts), s=100, zorder=1)
    plt.axhline(0, color='gray', zorder=0)

    total_x = np.linspace(pts[0] - 3*sigma, pts[i-1] + 3*sigma, 1000)
    total = sum([stats.norm.pdf(total_x, pts[j], sigma) for j in range(i)])
    plt.plot(total_x, total, color=blue, lw=3)
    plt.xlim(-3, 12)
    plt.ylim(-0.1, 1.5)
    plt.box(False)
    plt.xticks(range(9))
    plt.yticks([])
    plt.tight_layout();
    #plt.savefig(f'02KDE_addkernel{i}.svg');

# %%
plt.figure(figsize=(8,5))
plt.plot(total_x, total, color=blue, lw=3)
plt.scatter(pts, [0]*len(pts), s=100, zorder=1, alpha=0.5)
plt.axhline(0, color='gray', zorder=0)
plt.xlim(-3, 12)
plt.ylim(-0.1, 1.5)
plt.box(False)
plt.xticks(range(9))
plt.yticks([])
plt.tight_layout();

# %% [markdown]
# ### Other Kernels

# %%
plt.figure(figsize=(8, 5))

mu = pts[3]
variance = 1
sigma = np.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma), linestyle='--', color='gray', zorder=2)

plt.scatter(pts[3], [0], s=200, zorder=1)
plt.axhline(0, color='gray', zorder=0)
plt.ylim(-0.1, .5)
plt.box(False)
plt.xticks([])
plt.yticks([])
plt.tight_layout();

# %%
plt.figure(figsize=(8, 5))

def build_tri_kernel(x, center=0, sigma=1):
    m = 0.4/sigma
    if x < (center-sigma):
        return 0
    elif x < center:
        return m*x + m*(sigma-center)
    elif x < (center+sigma):
        return -m*x + m*(sigma + center)
    else:
        return 0  

mu = pts[3]
variance = 1
sigma = np.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, [build_tri_kernel(val, center=mu, sigma=1.5) for val in x], 
         linestyle='--', color='gray', zorder=2)
plt.scatter(pts[3], [0], s=200, zorder=1)
plt.axhline(0, color='gray', zorder=0)
plt.ylim(-0.1, .5)
plt.box(False)
plt.xticks([])
plt.yticks([])
plt.tight_layout();

# %%
plt.figure(figsize=(8, 5))

def build_cos_kernel(x, center=0, sigma=1):
    if np.abs(x - center) < sigma:
        return 0.4*np.cos(x-center)
    else:
        return 0  

mu = pts[3]
variance = 1
sigma = np.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, [build_cos_kernel(val, center=mu, sigma=1.5) for val in x], 
         linestyle='--', color='gray', zorder=2)
plt.scatter(pts[3], [0], s=200, zorder=1)
plt.axhline(0, color='gray', zorder=0)
plt.ylim(-0.1, .5)
plt.box(False)
plt.xticks([])
plt.yticks([])
plt.tight_layout();

# %% [markdown]
# ## Univariate (1D)

# %%
sns.kdeplot(cars.horsepower);

# %%
sns.kdeplot(cars.horsepower, shade=True);
# Out:
# C:\Users\dghos\AppData\Local\Temp\ipykernel_5728\1584878351.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(cars.horsepower, shade=True);

# %%
sns.kdeplot(cars.horsepower, bw=5);
# Out:
# C:\Users\dghos\AppData\Local\Temp\ipykernel_5728\804108213.py:1: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=5`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.13.0.
#
#   sns.kdeplot(cars.horsepower, bw=5);

# %%
sns.kdeplot(cars.horsepower, cumulative=True);

# %% [markdown]
# ### Bandwidth Widget

# %%
from ipywidgets import interact, interactive, HBox, VBox, interactive_output

from IPython.display import display

# %%
def bandwidth_widget(bw=10):
    sns.kdeplot(cars.horsepower, bw=bw, lw=3, shade=True)
    plt.xlim(-30, 300)
    plt.ylim(0, 0.03)

# %%
interactive(bandwidth_widget, bw=(1, 30, 1))
# Out:
# interactive(children=(IntSlider(value=10, description='bw', max=30, min=1), Output()), _dom_classes=('widget-i…

# %% [markdown]
# ## Bivariate (2D)

# %% [markdown]
# ### Bivariate Intro

# %%
sns.set_style('darkgrid')

# %%
#sns.kdeplot(x = cars.horsepower, y = cars.mpg)
sns.scatterplot(x = cars.horsepower, y = cars.mpg, color='black', alpha=0.7, s=20)
plt.xlim(0, 260)
plt.ylim(0, 55)
plt.xlabel('Horsepower', fontsize=16)
plt.ylabel('MPG', fontsize=16)
plt.tight_layout();

# %%
sns.kdeplot(x = cars.horsepower, y = cars.mpg)
sns.scatterplot(x = cars.horsepower, y = cars.mpg, color='black', alpha=0.7, s=20, zorder=10)
plt.xlim(0, 260)
plt.ylim(0, 55)
plt.xlabel('Horsepower', fontsize=14)
plt.ylabel('MPG', fontsize=14)
plt.tight_layout();

# %%
sns.kdeplot(x = cars.horsepower, y = cars.mpg)
#sns.scatterplot(cars.horsepower, cars.mpg, color='black', alpha=0.7, s=20, zorder=10)
plt.xlim(0, 260)
plt.ylim(0, 55)
plt.xlabel('Horsepower', fontsize=14)
plt.ylabel('MPG', fontsize=14)
plt.tight_layout();

# %% [markdown]
# ### Bivariate Demo

# %%
sns.kdeplot(x = cars.horsepower, y = cars.mpg)

plt.show()

# %%
sns.kdeplot(x=cars.horsepower, y=cars.mpg, n_levels=16);

# %%
sns.kdeplot(x=cars.horsepower, y=cars.mpg, fill=True);

# %%
sns.set_style('whitegrid')

sns.kdeplot(x=cars.horsepower, y=cars.mpg, 
            fill=True,
            thresh = 0.06
           );

# %%
sns.kdeplot(x=cars.horsepower, y=cars.mpg, 
            fill=True, 
            cbar=True
           );

# %% [markdown]
# ## Bivariate KDEplot by Category

# %%
sns.set_style('whitegrid')

cyl_4 = cars[cars.cylinders==4]
cyl_8 = cars[cars.cylinders==8]

plt.figure(figsize=(8,6))

sns.kdeplot(x=cyl_4.horsepower, y=cyl_4.mpg,
            cmap="Blues", shade=True, shade_lowest=False)
sns.kdeplot(x=cyl_8.horsepower, y=cyl_8.mpg,
            cmap="Reds", shade=True, shade_lowest=False)

plt.xlabel('Horsepower', fontsize=14)
plt.ylabel('Miles per Gallon (MPG)', fontsize=14)

plt.annotate("4 Cylinders", (105, 32), color=blue, fontsize=16, fontweight='bold')
plt.annotate("8 Cylinders", (190, 18), color=red, fontsize=16, fontweight='bold');
# Out:
# C:\Users\dghos\AppData\Local\Temp\ipykernel_5728\2119500175.py:8: UserWarning:
#
# `shade_lowest` has been replaced by `thresh`; setting `thresh=0.05.
# This will become an error in seaborn v0.13.0; please update your code.
#
#   sns.kdeplot(x=cyl_4.horsepower, y=cyl_4.mpg,
# C:\Users\dghos\AppData\Local\Temp\ipykernel_5728\2119500175.py:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=cyl_4.horsepower, y=cyl_4.mpg,
# C:\Users\dghos\AppData\Local\Temp\ipykernel_5728\2119500175.py:10: UserWarning:
#
# `shade_lowest` has been replaced by `thresh`; setting `thresh=0.05.
# This will become an error in seaborn v0.13.0; please update your code.
#
#   sns.kdeplot(x=cyl_8.horsepower, y=cyl_8.mpg,
# C:\Users\dghos\AppData\Local\Temp\ipykernel_5728\2119500175.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x=cyl_8.horsepower, y=cyl_8.mpg,

# %% [markdown]
# ## Other Figures that use KDE

# %%
plt.figure(figsize=(8,5))
sns.distplot(hp, kde_kws={"lw": 5}, hist_kws={'alpha': 0.25})

sns.despine(left=True)
plt.xlim(0, 280)
plt.xlabel('')
plt.yticks([])
plt.tight_layout();

# %%
sns.pairplot(cars[cars.cylinders.isin([4,6,8])], 
             hue='cylinders', 
             vars=['mpg', 'horsepower', 'acceleration'], 
             palette='inferno_r'
            );
