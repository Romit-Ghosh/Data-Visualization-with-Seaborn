# %% [markdown]
# # Seaborn: countplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
diamonds = sns.load_dataset('diamonds')

diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds = diamonds[diamonds.clarity.isin(['SI1', 'VS2'])]

diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 7       0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8       0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 10      0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53933   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72  3.49
# 53934   0.72    Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
#
# [25323 rows x 10 columns]

# %%
diamonds.shape
# Out:
# (25323, 10)

# %% [markdown]
# ## Basics

# %%
sns.set_style('darkgrid')

# %%
sns.countplot(x='color', data=diamonds);

# %%
diamonds.color.value_counts(sort=False)
# Out:
# D    3780
# E    4896
# F    4332
# G    4323
# H    3918
# I    2593
# J    1481
# Name: color, dtype: int64

# %%
diamonds.color.value_counts(sort= True)
# Out:
# E    4896
# F    4332
# G    4323
# H    3918
# D    3780
# I    2593
# J    1481
# Name: color, dtype: int64

# %% [markdown]
# ### Horizontal Countplot

# %%
sns.countplot(y='color', data=diamonds);

# %% [markdown]
# ## Options

# %% [markdown]
# ### `order`

# %%
sns.countplot(x='color', data=diamonds);

# %%
sns.countplot(x='cut', data=diamonds);

# %%
sns.countplot(x='cut', data=diamonds);

plt.tick_params(
    labelbottom= False,
    labeltop= True
)

# %%
diamonds.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
diamonds.color.cat.categories
# Out:
# Index(['D', 'E', 'F', 'G', 'H', 'I', 'J'], dtype='object')

# %%
diamonds.cut.cat.categories
# Out:
# Index(['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], dtype='object')

# %%
diamonds.clarity.cat.categories
# Out:
# Index(['IF', 'VVS1', 'VVS2', 'VS1', 'VS2', 'SI1', 'SI2', 'I1'], dtype='object')

# %%
color_order=['J', 'I', 'H', 'G', 'F', 'E', 'D']  # for customized ordering of the plot

sns.countplot(x='color', data=diamonds, order=color_order);

# %% [markdown]
# ### Order Ascending or Descending

# %%
diamonds.color.value_counts().index
# Out:
# CategoricalIndex(['E', 'F', 'G', 'H', 'D', 'I', 'J'], categories=['D', 'E', 'F', 'G', 'H', 'I', 'J'], ordered=False, dtype='category')

# %%
sns.countplot(x='color', data=diamonds,
              order=diamonds.color.value_counts().index  # ascending
             );

# %%
sns.countplot(x='color', data=diamonds,
              order=diamonds.color.value_counts().index[::-1]  #remove [::-1] for descending
             );

# %% [markdown]
# ### `hue`, `hue_order`

# %%
sns.countplot(x='color', data=diamonds, hue='clarity', hue_order=['SI1', 'VS2']);

# %% [markdown]
# ## Styling

# %% [markdown]
# ### `color` and `palette`

# %%
sns.countplot(x='color', data=diamonds, color='skyblue');  # color parameter so as to make all the bars look the same color

# %%
sns.countplot(x='color', data=diamonds, palette='twilight');

# %%
diamonds.color.value_counts()
# Out:
# E    4896
# F    4332
# G    4323
# H    3918
# D    3780
# I    2593
# J    1481
# Name: color, dtype: int64

# %% [markdown]
# ### Other Matplotlib Properties

# %%
sns.countplot(x='color', data=diamonds,
              lw=6, ec='black', hatch='/'  # ec= edge color
             );

# %% [markdown]
# ## Examples, Thumbnail

# %%
from matplotlib import pyplot as plt

# %%
sns.set(style='darkgrid', font_scale=1.3)
sns.countplot(x='cut', data=diamonds, color='blue', lw=3, ec= 'yellow')
plt.xlabel('')
plt.ylabel('Count')


plt.tight_layout()
#plt.savefig('20countplot_image_countplotExample.png', dpi=200);

# %%
sns.set_style('white')

import pandas as pd

df = pd.DataFrame({'Animal': ['dog', 'cat', 'cat', 'dog', 'dog', 'cat', 'dog', 'cow'],
                   'Weight': [55, 8, 12, 25, 100, 10, 60, 260]
                  })

# %%
df
# Out:
#   Animal  Weight
# 0    dog      55
# 1    cat       8
# 2    cat      12
# 3    dog      25
# 4    dog     100
# 5    cat      10
# 6    dog      60
# 7    cow     260

# %%
plt.figure(figsize=(3, 3))

sns.countplot(x='Animal', data=df, ec='black', lw=3, palette=['darkred', '#2F8F8F', 'blue'])

plt.yticks([0, 1, 2, 3, 4])
plt.ylabel('Count', labelpad=20)

sns.despine()

plt.tight_layout()
#plt.savefig('21countplot_figure_dogsCats.svg');

# %%
result = df.groupby('Animal').Weight.mean().to_frame().rename_axis('A')
result
# Out:
#      Weight
# A
# cat    10.0
# cow   260.0
# dog    60.0

# %%
result = df.groupby('Animal').Weight.mean().to_frame().reset_index().rename(columns={'Animal': 'A'})
result
# Out:
#      A  Weight
# 0  cat    10.0
# 1  cow   260.0
# 2  dog    60.0

# %%
plt.figure(figsize=(5, 6))

sns.barplot(x='Animal', y='Weight', data=df, ec='black', lw=3, 
            palette=['darkred', '#2F8F8F'],
            errorbar=None
           )

plt.ylim(0, 75)
plt.ylabel('Weight', labelpad=20)

sns.despine()

plt.tight_layout()
#plt.savefig('21countplot_figure_dogsCats_bar_noCI.svg');

# %%
plt.figure(figsize=(3, 6))

sns.barplot(x='Animal', y='Weight', data=df, ec='black', lw=3, 
            palette=['darkred', '#2F8F8F'],
            errorbar=('ci', 68), errcolor='black'
           )

plt.ylim(0, 75)
plt.ylabel('Weight', labelpad=20)

sns.despine()

plt.tight_layout()
#plt.savefig('21countplot_figure_dogsCats_bar_withCI.svg');

# %% [markdown]
# ### Thumb

# %%
plt.figure(figsize=(7,4))
sns.set(style='white', font_scale=1.2)

ax = sns.countplot(
                   x='color', data=diamonds, 
                   hue='clarity', hue_order=['SI1', 'VS2'], 
                   palette=['#2F8F8F', 'lightgray']
                  )

ax.legend([], frameon=False)
sns.despine()

plt.xlabel('')
plt.ylabel('Count', labelpad=10)
plt.tight_layout()
plt.savefig('21countplot_image_thumb.png', dpi=260);

# %%
diamonds.value_counts(sort= True)
# Out:
# carat  cut        color  clarity  depth  table  price  x     y     z
# 0.79   Ideal      G      SI1      62.3   57.0   2898   5.90  5.85  3.66    5
# 0.36   Ideal      D      SI1      62.7   57.0   663    4.54  4.59  2.86    2
# 0.31   Good       D      SI1      63.5   56.0   571    4.29  4.31  2.73    2
# 0.41   Premium    G      VS2      61.4   59.0   827    4.75  4.79  2.93    2
# 0.31   Ideal      H      VS2      63.0   57.0   628    4.34  4.32  2.73    2
#                                                                           ..
# 0.51   Very Good  J      VS2      58.0   62.0   1008   5.24  5.27  3.05    1
#                   I      SI1      63.5   60.0   1046   5.03  5.05  3.20    1
#                                          55.0   1068   5.07  5.11  3.23    1
#                                   63.1   56.0   1052   5.14  5.06  3.22    1
# 3.51   Premium    J      VS2      62.5   59.0   18701  9.66  9.63  6.03    1
# Length: 25261, dtype: int64

# %%
diamonds.color
# Out:
# 1        E
# 3        I
# 7        H
# 8        E
# 10       J
#         ..
# 53933    E
# 53934    D
# 53935    D
# 53936    D
# 53937    D
# Name: color, Length: 25323, dtype: category
# Categories (7, object): ['D', 'E', 'F', 'G', 'H', 'I', 'J']

# %%
diamonds.color.value_counts  # does not actrually call the value_counts() method, it is just the reference to the method
# Out:
# <bound method IndexOpsMixin.value_counts of 1        E
# 3        I
# 7        H
# 8        E
# 10       J
#         ..
# 53933    E
# 53934    D
# 53935    D
# 53936    D
# 53937    D
# Name: color, Length: 25323, dtype: category
# Categories (7, object): ['D', 'E', 'F', 'G', 'H', 'I', 'J']>
